# %%
#21BCE4002 ADITHYA MOMIDI
import pandas as pd
import numpy as np

# %%
# Task 1
data=np.random.rand(4,4) #random numers from [0,1) shape is 4x4
df=pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.103039  0.658899  0.436879  0.805985
# 1  0.158899  0.333634  0.695688  0.701443
# 2  0.064355  0.486386  0.916797  0.925186
# 3  0.189848  0.115297  0.383750  0.794053

# %%
#Task 2
columnName=['Random value 1','Random value 2','Random value 3','Random value 4']
df.columns=columnName
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.103039        0.658899        0.436879        0.805985
# 1        0.158899        0.333634        0.695688        0.701443
# 2        0.064355        0.486386        0.916797        0.925186
# 3        0.189848        0.115297        0.383750        0.794053

# %%
#Task 3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.129035        0.398554        0.608278        0.806667
# std          0.056123        0.230899        0.246722        0.091794
# min          0.064355        0.115297        0.383750        0.701443
# 25%          0.093368        0.279049        0.423596        0.770901
# 50%          0.130969        0.410010        0.566283        0.800019
# 75%          0.166636        0.529514        0.750965        0.835785
# max          0.189848        0.658899        0.916797        0.925186

# %%
#Task 4
df.isnull().any().any() #to check if there is any null values in df
# Out:
# False

# %%
#Task 5
print("\nUsing label location\n",df.loc[:,'Random value 2':'Random value 3'],"\n")
print("Using index location\n",df.iloc[:,1:3])
# Out:
# Using label location
#     Random value 2  Random value 3
# 0        0.658899        0.436879
# 1        0.333634        0.695688
# 2        0.486386        0.916797
# 3        0.115297        0.383750
#
# Using index location
#     Random value 2  Random value 3
# 0        0.658899        0.436879
# 1        0.333634        0.695688
# 2        0.486386        0.916797
# 3        0.115297        0.383750
